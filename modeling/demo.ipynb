# %%
import plotly.express as px
import pandas as pd
import config
from web.shared_utils import load_data, get_keyword_grant_links, expand_grants_to_years

# %%
keywords, grants, cats = load_data()

# %%
cats.groupby()
# Out:
#                                                                                           description  \
# name
# Climate and Paleoenvironmental Reconstruction       A unified domain integrating climate variabili...
# Fossilisation, Biological Preservation, and Pal...  This category explores the scientific processe...
# Evolutionary and Paleobiological Foundations        This category explores the deep evolutionary h...
# Australian Paleontological and Vertebrate Fossils   This category centers on the fossil record of ...
# Natural Heritage, Fossil Record and Evolutionar...  This category highlights the scientific and co...
# ...                                                                                               ...
# Defence and Security Applications of Robotics a...  This category explores the integration of robo...
# Nanotechnology and Emerging Materials in Security   This category addresses the application of nan...
# Defense and Security Applications                   A domain focused on the application of advance...
# National Security, Defence, and Strategic Policy    A category encompassing the strategic, policy,...
# Defense, Security, and National Technologies        A specialized domain addressing technologies w...
#
#                                                       field_of_research  \
# name
# Climate and Paleoenvironmental Reconstruction       BIOLOGICAL_SCIENCES
# Fossilisation, Biological Preservation, and Pal...  BIOLOGICAL_SCIENCES
# Evolutionary and Paleobiological Foundations        BIOLOGICAL_SCIENCES
# Australian Paleontological and Vertebrate Fossils   BIOLOGICAL_SCIENCES
# Natural Heritage, Fossil Record and Evolutionar...  BIOLOGICAL_SCIENCES
# ...                                                                 ...
# Defence and Security Applications of Robotics a...          ENGINEERING
# Nanotechnology and Emerging Materials in Security           ENGINEERING
# Defense and Security Applications                           ENGINEERING
# National Security, Defence, and Strategic Policy            ENGINEERING
# Defense, Security, and National Technologies                ENGINEERING
#
#                                                                                              keywords
# name
# Climate and Paleoenvironmental Reconstruction       [Australia's flooding history, Australian clim...
# Fossilisation, Biological Preservation, and Pal...                          [fossilisation processes]
# Evolutionary and Paleobiological Foundations        [Australia's oldest complex organisms, Cambria...
# Australian Paleontological and Vertebrate Fossils   [Australian dinosaurs, Australian tetrapod tra...
# Natural Heritage, Fossil Record and Evolutionar...  [Australia's natural heritage, Cambrian fossil...
# ...                                                                                               ...
# Defence and Security Applications of Robotics a...  [defence industry, information and communicati...
# Nanotechnology and Emerging Materials in Security                                    [nanotechnology]
# Defense and Security Applications                   [IoT experimental facility, Joint Strike Fight...
# National Security, Defence, and Strategic Policy    [Defence technologies, civil and defence teles...
# Defense, Security, and National Technologies        [Grid computing security, adaptive fusion, app...
#
# [2954 rows x 3 columns]
