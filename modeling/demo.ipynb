# %%
import pandas as pd

# %%
df = pd.read_json("results/keyword_evaluations.jsonl", lines=True)

# %%
df.iloc[1]
# Out:
# keyword_name                                  Normalisation Process Theory
# source_grant_id                                            arc/lp110200261
# score                                                                   10
# quality                                                          Excellent
# is_present_in_text                                                    True
# is_specific                                                           True
# is_unique                                                             True
# is_appropriate_length                                                 True
# reasoning                The keyword 'Normalisation Process Theory' is ...
# Name: 1, dtype: object

# %%
df
# Out:
#                        keyword_name  source_grant_id  score    quality  \
# 0            constraint programming    arc/lp0349346      9  Excellent
# 1      Normalisation Process Theory  arc/lp110200261     10  Excellent
# 2           experimental techniques  arc/dp130103619      9  Excellent
# 3            genetic susceptibility     nhmrc/426702     10  Excellent
# 4         evolutionary consequences    arc/dp0345500      9  Excellent
# ...                             ...              ...    ...        ...
# 17952                immune evasion    nhmrc/1065696      9  Excellent
# 17953        Steel Institute (ISPP)    arc/le0347258      7       Good
# 17954          early warning system    nhmrc/1102286      6       Fair
# 17955   regional peace and security    arc/dp0450986      8       Good
# 17956              array waveguides    arc/dp0211435      8  Excellent
#
#        is_present_in_text  is_specific  is_unique  is_appropriate_length  \
# ...
