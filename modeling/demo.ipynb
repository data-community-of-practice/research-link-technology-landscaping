# %%
import plotly.express as px
import pandas as pd
import config
from web.shared_utils import load_data, get_keyword_grant_links, expand_grants_to_years

# %%
keywords, grants, cats = load_data()

# %%
kw_grants = get_keyword_grant_links(keywords)

# %%
grants_years = expand_grants_to_years(grants)

# %%
grants_years[grants_years.grant_id == "arc/le0775612"]
# Out:
#         grant_id  year  funding_amount
# 0  arc/le0775612  2007        350000.0
# 1  arc/le0775612  2008        350000.0
